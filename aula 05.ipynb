# %%
#AULA 05 - 08/04/26 - OBJETOS COMPOSTOS MULTIDIMENSIONAIS

# %%
matrix = [
[1,2],
[3,4],
[5,6],
[7,8]
]
matrix
# Out:
# [[1, 2], [3, 4], [5, 6], [7, 8]]

# %%
matrix[0][0] = "1"
matrix
# Out:
# [['1', 2], [3, 4], [5, 6], [7, 8]]
