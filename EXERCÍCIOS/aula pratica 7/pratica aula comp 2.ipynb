# %%
simbolo = [
    "IFNG",
    "IL10",
    "TNF",
    "CSF2"
]
full_name = [
    'interferon gamma',
    'interleukin 10',
    'tumor necrosis factor',
    'colony stimulating factor 2'
]
source = [
    'HGNC:HGNC:5438',
    'RGD:2886',
    'MGI:MGI:104798',
    'HGNC:HGNC:2434'
]
gene_type = [
    'protein coding',
    'protein coding',
    'protein coding',
    'protein coding'
]
organism = [
    'Homo sapiens',
    'Ratturs norveticus',
    'Mus musculus',
    'Homo sapiens'
]
chromosome = [
    12,
    13,
    17,
    5
]

# %%
gene_matriz_lista = [
    simbolo,
    full_name,
    source,
    gene_type,
    organism,
    chromosome
]
gene_matriz_lista
# Out:
# [['IFNG', 'IL10', 'TNF', 'CSF2'],
#  ['interferon gamma',
#   'interleukin 10',
#   'tumor necrosis factor',
#   'colony stimulating factor 2'],
#  ['HGNC:HGNC:5438', 'RGD:2886', 'MGI:MGI:104798', 'HGNC:HGNC:2434'],
#  ['protein coding', 'protein coding', 'protein coding', 'protein coding'],
#  ['Homo sapiens', 'Ratturs norveticus', 'Mus musculus', 'Homo sapiens'],
#  [12, 13, 17, 5]]

# %%
# .pop retira o objeto
# .append insere objeto 
# gene_array[:,0] significa todas as linhas (:) na coluna 0
# gene_array [-1,:] última linha (-1) e todas as colunas (:)
# gene_array [0,1] = elemento da linha 0 e coluna 1
