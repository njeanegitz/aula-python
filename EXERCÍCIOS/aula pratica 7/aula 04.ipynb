# %%
tupla = (1,2,3,4,5)
tupla
# Out:
# (1, 2, 3, 4, 5)

# %%
type(tupla)
# Out:
# tuple

# %%
lista = [1,2,3,4,5,6]
lista
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
type(lista)
# Out:
# list

# %%
dicionario = {"a": 1, "b": 2, "c":3}
dicionario
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
tupla[1]
# Out:
# 2

# %%
lista
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
type(lista[4])
# Out:
# int

# %%
print(type(lista[4]))
# Out:
# <class 'int'>

# %%
lista[-2:]
# Out:
# [5, 6]

# %%
('q','w','e','r','t','y')
type(('q','w','e','r','t','y'))
# Out:
# tuple

# %%
tupla
# Out:
# (1, 2, 3, 4, 5)

# %%
tupla = ('q','w','e','r','t','y')

# %%
tupla
# Out:
# ('q', 'w', 'e', 'r', 't', 'y')

# %%
lista.append('8')

# %%
lista
# Out:
# [1, 2, 3, 4, 5, 6, '6', '7', '8']

# %%
print(f"Lista legal: {lista}")
# Out:
# Lista legal: [1, 2, 3, 4, 5, 6, '6', '7', '8']

# %%
lista = [1,2,3,4,5,6]

# %%
lista
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
dicionario = {'a':1, 'b':2, 'c':3}
dicionario
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
dicionario[1] = "abacaxi"
dicionario
# Out:
# {'a': 1, 'b': 2, 'c': 3, 1: 'abacaxi'}

# %%
lista.pop()
#lista.pop() DELETA o último número da lista!
# Out:
# 4

# %%
print(lista)
print(lista.pop(1))
#isso faz tirar um elemento específico da lista!
# Out:
# [1, 2, 3]
# 2

# %%
lista
# Out:
# [1, 3]
