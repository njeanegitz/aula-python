# %%
# OPERADORES LOGICOS
# and e or

# %%
#para AND ambas as expressões precisam ser verdadeiras para o resultado ser verdadeiro
1 == 1 and 2 == 2
# Out:
# True

# %%
# para OR basta que uma das expressões seja verdadeira para o resultado ser verdadeiro
1 == 1 or 2 == 3
# Out:
# True

# %%
# IN me diz se algo está dentro do outro
1 in [1,2,3]
# Out:
# True

# %%
print('1' in [1,2,3])
print('1' in '[1,2,3]')
# Out:
# False
# True

# %%
p = 1
q = p
p is q
# Out:
# True

# %%
# axis=columns (colunas por linhas) e axis=index (linhas por colunas)

# %%
# df[1,:]==df da terceira OR df da quarta == df da quinta
