# %% [markdown]
# # Exercício:

# %% [markdown]
# ## 01 – Dados as operações abaixo, em Python, qual o resultado da operação lógica:
# p and q and r and s and t?
# <br>
# <br>Imprima os objetos e o resultado usando uma estrutura condicional.
#
# <br>p = 2.0 + 3.0 / 5.0 == 10
# <br>q = (p + 10.2) - 5.0 * 2.0 <= 2.9
# <br>r = 10 <= p / q + 33.8 < 100
# <br>s = 5 != p / (q + r)
# <br>t = 33 == s * 2

# %%
p = 2.0 + 3.0 / 5.0 == 10
q = (p + 10.2) - 5.0 * 2.0 <= 2.9
r = 10 <= p / q + 33.8 < 100
s = 5 != p / (q + r)
t = 33 == s * 2

# %%
print(p)
print(q)
print(r)
print(s)
print(t)
# Out:
# False
# True
# True
# True
# False

# %%
if p and q and r and s and t:
    print("é verdadii")
else:
    print("alguém tá mentindo")
# Out:
# alguém tá mentindo

# %% [markdown]
# ## Instancie um objeto da classe array numpy, contendo 5 valores quantitativos randômicos normalmente distribuídos, com média 10 e desvio padrão 3.
# Quantos e quais são os valores superiores a 10?

# %% [markdown]
# ## 02 – Descreva o racional da sua resposta:

# %% [markdown]
# R.: Para cada um valores instanciados, avaliar de é maior que 10. Se for >10, imprimir o valor. Se não for, não voltar nenhuma resposta.
# E por último, somar quantos valores são >10.

# %% [markdown]
# ## 03 – Desenhe o fluxograma da resposta:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 04 – Escreva o programa em Python:

# %%
import numpy as np

# %%
array_1 = np.random.normal(10,3,5)
array_1
# Out:
# array([13.5335613 ,  6.49969439,  5.26477658, 12.51048039, 15.51395095])

# %%
for valor in array_1:
    if valor > 10:
        print(valor)
soma = np.sum(array_1 >10)
print(f"valores maiores que 10: {soma}")
# Out:
# 13.533561297834638
# 12.510480394044325
# 15.513950954754034
# valores maiores que 10: 3

# %% [markdown]
# ## 05 – Seria possível, com o racional proposto, saber quantos e quais valores são superiores a 20? Porque?

# %% [markdown]
# R: Como a função pega valores com média 10 e desvio padrão de 3, é pouco provável que existam valores maiores que 20, mas usando o racional do exercício 4 é possível saber esse valores mudando o valor 10 para 20.

# %%
for valor in array_1:
    if valor >20:
        print(valor)
soma = np.sum(array_1 >20)
print(f"valores maiores que 20: {soma}")
# Out:
# valores maiores que 20: 0

# %% [markdown]
# ## 06 – Instancie um objeto da classe lista com os valores obtidos no exercício 02.
#
# O valor 10.453444246931676 está presente?

# %%
lista = array_1.tolist()
lista
# Out:
# [13.533561297834638,
#  6.49969438948318,
#  5.264776581442081,
#  12.510480394044325,
#  15.513950954754034]

# %%
10.453444246931676 == lista
# Out:
# False

# %%
for valor in lista:
    if valor == 10.453444246931676:
        print(f"está presente!")
    if not valor == 10.453444246931676:
        print(f"não tem!")
# Out:
# não tem!
# não tem!
# não tem!
# não tem!
# não tem!

# %% [markdown]
# ## No exercício 7 da aula 6, foi instanciado um objeto da classe DataFrame. Exporte (usando nome_data_frame.to_csv(‘nome_arquivo.csv’)) para .csv estes dados e os importe (com pd.read_csv(‘nome_arquivo.csv’) aqui. Edite o objeto para que os index sejam os nomes dos genes e para que as colunas sejam facilmente identificadas. Usando o número de caracteres do primeiro gene, quero saber a informação gênica. Caso o nome tenha entre 2 e 4 caracteres inclusive, posso saber as informações do gene? Porém, caso tenha menos de 2 caracteres, posso saber todos os valores nas instâncias onde os números de caracteres dos nomes são superiores a 4? Ainda, caso tenha mais de 4 caracteres, apenas me informe quem é superior.

# %% [markdown]
# ## 07 – Descreva o racional da sua resposta:

# %% [markdown]
# R.: Primeiro, fazer a leitura do número de caracteres do primeiro gene (posição 0).
# Se o número de caracteres estiver entre 2 e 4 (incluindo ambos) = imprimir as informações do gene.
# Se não, perguntar se tem menos de 2 caracteres e, caso houver, imprimir os genes com mais de 4 caracteres.
# Se não houver, pergutnar se tem mais de 4 caracteres e, caso houver, imprimir o nome do gene com o maior número de caracteres.

# %% [markdown]
# ## 08 – Desenhe o fluxograma da resposta:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 09 – Escreva o programa em Python:

# %%
import pandas as pd

# %%
df_genes = pd.read_csv("df_genes.csv", index_col=0)
df_genes
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df_genes = pd.read_csv("df_genes.csv", index_col=0)
#       2 df_genes
#
# File c:\Users\Home\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df_genes["caracteres"] = pd.to_numeric(df_genes["caracteres"])
gene_um = df_genes.index[0]
n_caracteres = df_genes.iloc[0]["caracteres"]
tamanho = df_genes["caracteres"]

# %%
if 2 <= n_caracteres <= 4:
    print(f"infos do primeiro gene:")
    print(df_genes[primeiro_gene])
elif n_caracteres <2:
    print(f"genes com mais de 4 caracteres:")
    print(df_genes[tamanho > 4])
elif n_caracteres >4:
    print(f"genes com mais caracteres:")
    print(df_genes[tamanho > 4])
# Out:
# genes com mais caracteres:
#            caracteres dois_primeiros  contagem_a  tem_hu
# TNF-alpha           9             TN           2   False
# BRCA1               5             BR           0   False
# LAMB3               5             LA           0   False
# HDAC1               5             HD           0   False

# %% [markdown]
# ## 10 – Caso a DataFrame contenha 10 milhões de entradas, este racional utilizado poderia responder as mesmas perguntas? Porque?

# %% [markdown]
# R.: Sim, o racional continua válido porque a lógica das condições não depende do tamanho da DataFrame, mas não é eficiente para grandes volumes de dados devido ao maior custo de tempo e memória.
