# %% [markdown]
# # Exercício:

# %% [markdown]
# ## 01 – Cite três vantagens do uso das funções e duas características que toda função deva ter?

# %% [markdown]
# R.: As vantagens são organização dos códigos, otimização de dados, por não executar tudo ao mesmo tempo, e a correção facilitada. Toda função tem um nome (identificador) e executa uma tarefa específica.

# %% [markdown]
# ## Responda a pergunta do exercício 2 da aula 10, usando funções:<br>
# Instancie um objeto da classe NumPy array, contendo 5 valores quantitativos randômicos normalmente distribuídos, com média 10 e desvio padrão 3.<br><br>
# Quantos e quais são os valores superiores a 10?

# %% [markdown]
# ## 02 – Descreva o racional da sua resposta:

# %% [markdown]
# R.: A partir do array é criado o objeto "maiores", que filtra todos os valores que são maiores que 10 e adiciona nesse objeto. É criado o objeto "quantidades" e calcula quantos valores estão em "maiores", e depois retorna os dois objetos.

# %% [markdown]
# ## 03 – Desenhe o fluxograma da resposta:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 04 – Escreva o programa em Python:

# %%
import numpy as np

# %%
array_4 = np.random.normal(10, 3, 5)
array_4
# Out:
# array([12.27054234, 12.93231677, 13.91917777,  6.63778077, 10.20587289])

# %%
def dez(array):
    maiores = array[array>10]
    quantidade = len(maiores)
    return f""""
quantidade: {quantidade}
valores: {maiores}
"""

# %%
print(dez(array_4))
# Out:
# "
# quantidade: 4
# valores: [12.27054234 12.93231677 13.91917777 10.20587289]

# %% [markdown]
# ## 05 – Seria possível, com o racional proposto, saber quantos e quais valores são superiores a 20? Porque?

# %%
def vinte(array):
    maiores = array[array>20]
    quantidade = len(maiores)
    return f"""
quantidade: {quantidade}
valores: {maiores}
"""
print(vinte(array_4))
# Out:
# quantidade: 0
# valores: []

# %% [markdown]
# ## Desenvolva um programa de computador que retorne a média de um conjunto de valores.

# %% [markdown]
# ## 06 – Descreva o racional da sua resposta:

# %% [markdown]
# R.: Faz uma lista com valores aleatórios. Soma todos os valores e calcula a quantidade de valores, e, a partir disso, faz a média (soma / quantidade). No fim, retorna esse valor.

# %% [markdown]
# ## 07 – Desenhe o fluxograma da resposta:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 08 – Escreva o programa em Python:

# %%
valores = np.random.randint(0,100,7).tolist()
valores
# Out:
# [79, 29, 60, 61, 51, 39, 89]

# %%
def calcular_media(lista):
    soma = sum(lista)
    quantidade = len(lista)
    media = soma / quantidade
    return media

# %%
print(calcular_media(valores))
# Out:
# 58.285714285714285

# %% [markdown]
# ## 09 – Desenvolva um programa de computador que retorne a divisão de dois objetos simples. Seu programa deve ser capaz de reconhecer a classe destes objetos e o valor, antes de retornar ao usuário.

# %%
#VER PRATICA 7 - 12-ROTINAS

# %%
def div_simples(a,b):
    print("a", type(a))
    print("b", type(b))
    resultado = a/b
    print("resultado:", type(resultado))
    return resultado

# %%
print(div_simples(45,2.9))
# Out:
# a <class 'int'>
# b <class 'float'>
# resultado: <class 'float'>
# 15.517241379310345

# %% [markdown]
# ## 10 – Desenvolva um programa de computador que retorne a divisão de dois objetos compostos. Seu programa deve ser capaz de reconhecer a classe destes objetos e o valor, antes de retornar ao usuário.

# %%
def div_listas(c, d):
    print("c:", type (c))
    print("d:", type (d))

    if len(c) != len(d):
        return "ops! as listas têm tamanhos diferentes!"
    resultado = []
    for i in range(len(c)):
        resultado.append(c[i] / d[i])

    print("resultado:", type(resultado))
    return resultado

# %%
lista1 = [2, 6]
lista2 = [30, 45, 80]

print(div_listas(lista1, lista2))
# Out:
# c: <class 'list'>
# d: <class 'list'>
# ops! as listas têm tamanhos diferentes!
